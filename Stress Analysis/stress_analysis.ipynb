# %%
import numpy as np
import pandas as pd
import re
import seaborn as sns
from PIL import Image
import os

# %%
df = pd.read_csv('final_stress_dataset.csv')

# %%
df['stress_inverted'] = 8 - df['stress']

# %%
df['obstacles_present'] = df['obst'] == 1
df['pavement_bad'] = df['pav'] == 0
df['parking_present'] = df['parked_veh'] == 1
df['no_crossing_present'] = df['cross'] == 0
df['bike_lane_absent'] = df['type3'] == 0
df['road_marking_absent'] = df['marking'] == 0
df['high_speed_present'] = df['type4'] == 0

# %%
def map_frequency_to_weight(frequency):
    if frequency == 4:
        return 1.0
    elif frequency in [2, 3]:
        return 0.6
    elif frequency == 1:
        return 0.3
    else:
        return 0.6

def assign_user_weight(row):
    if row['mode'] == 'car':
        return map_frequency_to_weight(row['car_frequency'])
    elif row['mode'] == 'ebike':
        return map_frequency_to_weight(row['bike_frequency'])
    elif row['mode'] == 'escooter':
        return map_frequency_to_weight(row['escooter_frequency'])
    elif row['mode'] == 'walk':
        return 1.0 
    else:
        return 0.6

# %%
df['user_weight'] = df.apply(assign_user_weight, axis=1)

# %%
stressor_conditions = {
    'obstacles': df['obstacles_present'] & (df['obstacles'] == 1),
    'pavement': df['pavement_bad'] & (df['pavement'] == 1),
    'parking': df['parking_present'] & (df['parking'] == 1),
    'no_crossing': df['no_crossing_present'] & (df['no_crossing'] == 1),
    'bike_lane': df['bike_lane_absent'] & (df['bike_lane'] == 1),
    'road_marking': df['road_marking_absent'] & (df['road_marking'] == 1),
    'speed': df['high_speed_present'] & (df['speed'] == 1),
    'traffic': df['traffic'] == 1
}

# %%
summary_tables = []

# %%
for stressor, condition in stressor_conditions.items():
    df_filtered = df[condition]
    summary = df_filtered.groupby(['mode', 'scenario']).apply(
        lambda g: (g['stress_inverted'] * g['user_weight']).sum() / g['user_weight'].sum()
    ).reset_index(name=f'weighted_avg_stress_{stressor}')
    summary_tables.append(summary)
# Out:
# C:\Users\Hasan Can Buldu\AppData\Local\Temp\ipykernel_13476\3319637929.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = df_filtered.groupby(['mode', 'scenario']).apply(
# C:\Users\Hasan Can Buldu\AppData\Local\Temp\ipykernel_13476\3319637929.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = df_filtered.groupby(['mode', 'scenario']).apply(
# C:\Users\Hasan Can Buldu\AppData\Local\Temp\ipykernel_13476\3319637929.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = df_filtered.groupby(['mode', 'scenario']).apply(
# C:\Users\Hasan Can Buldu\AppData\Local\Temp\ipykernel_13476\3319637929.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = df_filtered.groupby(['mode', 'scenario']).apply(
# C:\Users\Hasan Can Buldu\AppData\Local\Temp\ipykernel_13476\3319637929.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = df_filtered.groupby(['mode', 'scenario']).apply(
# C:\Users\Hasan Can Buldu\AppData\Local\Temp\ipykernel_13476\3319637929.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = df_filtered.groupby(['mode', 'scenario']).apply(
# C:\Users\Hasan Can Buldu\AppData\Local\Temp\ipykernel_13476\3319637929.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = df_filtered.groupby(['mode', 'scenario']).apply(
# C:\Users\Hasan Can Buldu\AppData\Local\Temp\ipykernel_13476\3319637929.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = df_filtered.groupby(['mode', 'scenario']).apply(

# %%
from functools import reduce

final_summary = reduce(
    lambda left, right: pd.merge(left, right, on=['mode', 'scenario'], how='outer'),
    summary_tables
)

# %%
final_summary
# Out:
#         mode    scenario  weighted_avg_stress_obstacles  \
# 0        car  scenario11                            NaN
# 1        car  scenario16                       3.279070
# 2        car  scenario17                            NaN
# 3        car   scenario3                       3.292308
# 4        car  scenario31                       4.454545
# 5        car  scenario36                            NaN
# 6      ebike  scenario11                            NaN
# 7      ebike  scenario16                       4.857143
# 8      ebike  scenario17                            NaN
# 9      ebike   scenario3                       3.666667
# 10     ebike  scenario31                       3.928571
# 11     ebike  scenario36                            NaN
# 12  escooter  scenario11                            NaN
# 13  escooter  scenario16                       4.857143
# 14  escooter  scenario17                            NaN
# 15  escooter   scenario3                       4.416667
# 16  escooter  scenario31                       3.588235
# 17  escooter  scenario36                            NaN
# 18      walk  scenario11                            NaN
# 19      walk  scenario16                       3.285714
# 20      walk  scenario17                            NaN
# 21      walk   scenario3                       3.714286
# 22      walk  scenario31                       3.250000
# 23      walk  scenario36                            NaN
#
#     weighted_avg_stress_pavement  weighted_avg_stress_parking  \
# 0                            NaN                     5.080000
# 1                       3.360000                          NaN
# 2                            NaN                          NaN
# 3                       2.774194                          NaN
# 4                            NaN                          NaN
# 5                            NaN                          NaN
# 6                            NaN                     5.000000
# 7                       5.500000                          NaN
# 8                            NaN                          NaN
# 9                       4.018519                          NaN
# 10                           NaN                          NaN
# 11                           NaN                          NaN
# 12                           NaN                     5.181818
# 13                      5.777778                          NaN
# 14                           NaN                          NaN
# 15                      4.500000                          NaN
# 16                           NaN                          NaN
# 17                           NaN                          NaN
# 18                           NaN                     3.000000
# 19                      4.000000                          NaN
# 20                           NaN                          NaN
# 21                      5.000000                          NaN
# 22                           NaN                          NaN
# 23                           NaN                          NaN
#
#     weighted_avg_stress_no_crossing  weighted_avg_stress_bike_lane  \
# 0                          4.500000                       4.739130
# 1                               NaN                       3.176471
# 2                               NaN                       3.660000
# 3                               NaN                            NaN
# 4                          4.400000                       4.361702
# 5                               NaN                            NaN
# 6                          3.200000                       4.600000
# 7                               NaN                       4.041667
# 8                               NaN                       4.347826
# 9                               NaN                            NaN
# 10                         3.000000                       3.480000
# 11                              NaN                            NaN
# 12                         3.500000                       4.692308
# 13                              NaN                       4.352941
# 14                              NaN                       4.431034
# 15                              NaN                            NaN
# 16                         2.967742                       3.293103
# 17                              NaN                            NaN
# 18                         3.714286                       2.500000
# 19                              NaN                       2.666667
# 20                              NaN                       1.000000
# 21                              NaN                            NaN
# 22                         3.307692                       3.000000
# 23                              NaN                            NaN
#
#     weighted_avg_stress_road_marking  weighted_avg_stress_speed  \
# 0                           4.408163                   7.000000
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                NaN                   3.909091
# 4                           4.375000                        NaN
# 5                                NaN                   2.545455
# 6                           4.583333                   5.285714
# 7                                NaN                        NaN
# 8                                NaN                        NaN
# 9                                NaN                   4.583333
# 10                          4.333333                        NaN
# 11                               NaN                   3.965517
# 12                          5.833333                   4.125000
# 13                               NaN                        NaN
# 14                               NaN                        NaN
# 15                               NaN                   4.400000
# 16                          4.000000                        NaN
# 17                               NaN                   4.571429
# 18                          3.000000                   3.428571
# 19                               NaN                        NaN
# 20                               NaN                        NaN
# 21                               NaN                   3.285714
# 22                          2.000000                        NaN
# 23                               NaN                   3.500000
#
#     weighted_avg_stress_traffic
# 0                      4.932432
# 1                      2.911765
# 2                      3.471429
# 3                      2.981818
# 4                      3.333333
# 5                      2.800000
# 6                      5.357143
# 7                      5.000000
# 8                      3.750000
# 9                      3.952381
# 10                     3.500000
# 11                     3.736842
# 12                     5.200000
# 13                     5.111111
# 14                     3.888889
# 15                     4.000000
# 16                     2.882353
# 17                     4.250000
# 18                     3.000000
# 19                     3.666667
# 20                     4.500000
# 21                     7.000000
# 22                     3.333333
# 23                     7.000000

# %%
def classify_weighted_stress(score):
    if pd.isna(score):
        return None
    elif score <= 2.2:
        return 'LTS 1'
    elif score <= 3.4:
        return 'LTS 2'
    elif score <= 4.6:
        return 'LTS 3'
    elif score <= 5.8:
        return 'LTS 4'
    else:
        return 'LTS 5'

# %%
for col in final_summary.columns:
    if 'weighted_avg_stress' in col:
        class_col = col.replace('weighted_avg_stress_', 'stress_class_')
        final_summary[class_col] = final_summary[col].apply(classify_weighted_stress)

# %%
final_summary
# Out:
#         mode    scenario  weighted_avg_stress_obstacles  \
# 0        car  scenario11                            NaN
# 1        car  scenario16                       3.279070
# 2        car  scenario17                            NaN
# 3        car   scenario3                       3.292308
# 4        car  scenario31                       4.454545
# 5        car  scenario36                            NaN
# 6      ebike  scenario11                            NaN
# 7      ebike  scenario16                       4.857143
# 8      ebike  scenario17                            NaN
# 9      ebike   scenario3                       3.666667
# 10     ebike  scenario31                       3.928571
# 11     ebike  scenario36                            NaN
# 12  escooter  scenario11                            NaN
# 13  escooter  scenario16                       4.857143
# 14  escooter  scenario17                            NaN
# 15  escooter   scenario3                       4.416667
# 16  escooter  scenario31                       3.588235
# 17  escooter  scenario36                            NaN
# 18      walk  scenario11                            NaN
# 19      walk  scenario16                       3.285714
# 20      walk  scenario17                            NaN
# 21      walk   scenario3                       3.714286
# 22      walk  scenario31                       3.250000
# 23      walk  scenario36                            NaN
#
#     weighted_avg_stress_pavement  weighted_avg_stress_parking  \
# 0                            NaN                     5.080000
# 1                       3.360000                          NaN
# 2                            NaN                          NaN
# 3                       2.774194                          NaN
# 4                            NaN                          NaN
# 5                            NaN                          NaN
# 6                            NaN                     5.000000
# 7                       5.500000                          NaN
# 8                            NaN                          NaN
# 9                       4.018519                          NaN
# 10                           NaN                          NaN
# 11                           NaN                          NaN
# 12                           NaN                     5.181818
# 13                      5.777778                          NaN
# 14                           NaN                          NaN
# 15                      4.500000                          NaN
# 16                           NaN                          NaN
# 17                           NaN                          NaN
# 18                           NaN                     3.000000
# 19                      4.000000                          NaN
# 20                           NaN                          NaN
# 21                      5.000000                          NaN
# 22                           NaN                          NaN
# 23                           NaN                          NaN
#
#     weighted_avg_stress_no_crossing  weighted_avg_stress_bike_lane  \
# 0                          4.500000                       4.739130
# 1                               NaN                       3.176471
# 2                               NaN                       3.660000
# 3                               NaN                            NaN
# 4                          4.400000                       4.361702
# 5                               NaN                            NaN
# 6                          3.200000                       4.600000
# 7                               NaN                       4.041667
# 8                               NaN                       4.347826
# 9                               NaN                            NaN
# 10                         3.000000                       3.480000
# 11                              NaN                            NaN
# 12                         3.500000                       4.692308
# 13                              NaN                       4.352941
# 14                              NaN                       4.431034
# 15                              NaN                            NaN
# 16                         2.967742                       3.293103
# 17                              NaN                            NaN
# 18                         3.714286                       2.500000
# 19                              NaN                       2.666667
# 20                              NaN                       1.000000
# 21                              NaN                            NaN
# 22                         3.307692                       3.000000
# 23                              NaN                            NaN
#
#     weighted_avg_stress_road_marking  weighted_avg_stress_speed  \
# 0                           4.408163                   7.000000
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                NaN                   3.909091
# 4                           4.375000                        NaN
# 5                                NaN                   2.545455
# 6                           4.583333                   5.285714
# 7                                NaN                        NaN
# 8                                NaN                        NaN
# 9                                NaN                   4.583333
# 10                          4.333333                        NaN
# 11                               NaN                   3.965517
# 12                          5.833333                   4.125000
# 13                               NaN                        NaN
# 14                               NaN                        NaN
# 15                               NaN                   4.400000
# 16                          4.000000                        NaN
# 17                               NaN                   4.571429
# 18                          3.000000                   3.428571
# 19                               NaN                        NaN
# 20                               NaN                        NaN
# 21                               NaN                   3.285714
# 22                          2.000000                        NaN
# 23                               NaN                   3.500000
#
#     weighted_avg_stress_traffic stress_class_obstacles stress_class_pavement  \
# 0                      4.932432                   None                  None
# 1                      2.911765                  LTS 2                 LTS 2
# 2                      3.471429                   None                  None
# 3                      2.981818                  LTS 2                 LTS 2
# 4                      3.333333                  LTS 3                  None
# 5                      2.800000                   None                  None
# 6                      5.357143                   None                  None
# 7                      5.000000                  LTS 4                 LTS 4
# 8                      3.750000                   None                  None
# 9                      3.952381                  LTS 3                 LTS 3
# 10                     3.500000                  LTS 3                  None
# 11                     3.736842                   None                  None
# 12                     5.200000                   None                  None
# 13                     5.111111                  LTS 4                 LTS 4
# 14                     3.888889                   None                  None
# 15                     4.000000                  LTS 3                 LTS 3
# 16                     2.882353                  LTS 3                  None
# 17                     4.250000                   None                  None
# 18                     3.000000                   None                  None
# 19                     3.666667                  LTS 2                 LTS 3
# 20                     4.500000                   None                  None
# 21                     7.000000                  LTS 3                 LTS 4
# 22                     3.333333                  LTS 2                  None
# 23                     7.000000                   None                  None
#
#    stress_class_parking stress_class_no_crossing stress_class_bike_lane  \
# 0                 LTS 4                    LTS 3                  LTS 4
# 1                  None                     None                  LTS 2
# 2                  None                     None                  LTS 3
# 3                  None                     None                   None
# 4                  None                    LTS 3                  LTS 3
# 5                  None                     None                   None
# 6                 LTS 4                    LTS 2                  LTS 4
# 7                  None                     None                  LTS 3
# 8                  None                     None                  LTS 3
# 9                  None                     None                   None
# 10                 None                    LTS 2                  LTS 3
# 11                 None                     None                   None
# 12                LTS 4                    LTS 3                  LTS 4
# 13                 None                     None                  LTS 3
# 14                 None                     None                  LTS 3
# 15                 None                     None                   None
# 16                 None                    LTS 2                  LTS 2
# 17                 None                     None                   None
# 18                LTS 2                    LTS 3                  LTS 2
# 19                 None                     None                  LTS 2
# 20                 None                     None                  LTS 1
# 21                 None                     None                   None
# 22                 None                    LTS 2                  LTS 2
# 23                 None                     None                   None
#
#    stress_class_road_marking stress_class_speed stress_class_traffic
# 0                      LTS 3              LTS 5                LTS 4
# 1                       None               None                LTS 2
# 2                       None               None                LTS 3
# 3                       None              LTS 3                LTS 2
# 4                      LTS 3               None                LTS 2
# 5                       None              LTS 2                LTS 2
# 6                      LTS 3              LTS 4                LTS 4
# 7                       None               None                LTS 4
# 8                       None               None                LTS 3
# 9                       None              LTS 3                LTS 3
# 10                     LTS 3               None                LTS 3
# 11                      None              LTS 3                LTS 3
# 12                     LTS 5              LTS 3                LTS 4
# 13                      None               None                LTS 4
# 14                      None               None                LTS 3
# 15                      None              LTS 3                LTS 3
# 16                     LTS 3               None                LTS 2
# 17                      None              LTS 3                LTS 3
# 18                     LTS 2              LTS 3                LTS 2
# 19                      None               None                LTS 3
# 20                      None               None                LTS 3
# 21                      None              LTS 2                LTS 5
# 22                     LTS 1               None                LTS 2
# 23                      None              LTS 3                LTS 5

# %%
final_summary.to_csv('stress_class.csv', index=False)
